# %% [markdown]
# # ML Test - Fabio Rodrigues

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# ## Importing the dataset

# %%
data_path = Path('research_centers.csv')

# %%
df = pd.read_csv(data_path)
df.head()
# Out:
#   researchCenterId  researchCenterName    city  latitude  longitude  \
# 0           RC-014  Research Center 14  City 4   50.7713    -1.9260
# 1           RC-040  Research Center 40  City 2   50.5088    -1.3637
# 2           RC-031  Research Center 31  City 4   50.2202    -1.2889
# 3           RC-046  Research Center 46  City 5   50.9362    -1.3040
# 4           RC-018  Research Center 18  City 2   50.0254    -1.8921
#
#    internalFacilitiesCount  hospitals_10km  pharmacies_10km  \
# 0                        3               1                0
# 1                        2               1                1
# 2                        3               0                1
# 3                       11               4                4
# 4                       10               4                5
#
#    facilityDiversity_10km  facilityDensity_10km
# 0                0.374488              0.177506
# 1                0.391903              0.108965
# 2                0.293552              0.076155
# 3                0.884502              0.697016
# 4                0.842611              0.568983

# %% [markdown]
# ### Inspect the data

# %%
# Overview of the dataset
df.describe()
# Out:
#         latitude  longitude  internalFacilitiesCount  hospitals_10km  \
# count  50.000000  50.000000                50.000000       50.000000
# mean   50.542770  -1.554638                 5.660000        1.860000
# std     0.320289   0.253853                 3.146816        1.340271
# min    50.007100  -1.976900                 1.000000        0.000000
# 25%    50.240375  -1.747225                 3.000000        1.000000
# 50%    50.635350  -1.561000                 5.000000        2.000000
# 75%    50.831475  -1.374175                 8.750000        3.000000
# max    50.994600  -1.049300                11.000000        4.000000
#
#        pharmacies_10km  facilityDiversity_10km  facilityDensity_10km
# count        50.000000               50.000000             50.000000
# mean          2.240000                0.568843              0.321164
# std           1.684988                0.249511              0.182562
# min           0.000000                0.119515              0.056541
# 25%           1.000000                0.344145              0.173814
# 50%           2.000000                0.585503              0.297584
# 75%           3.000000                0.800489              0.476387
# max           5.000000                0.992984              0.697016

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# researchCenterId           0
# researchCenterName         0
# city                       0
# latitude                   0
# longitude                  0
# internalFacilitiesCount    0
# hospitals_10km             0
# pharmacies_10km            0
# facilityDiversity_10km     0
# facilityDensity_10km       0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Number of cities

# %%
## Number of cities
number_of_cities = np.sort(df['city'].unique())
print(f"List of cities: {number_of_cities}")
print(f"Number of cities: {number_of_cities.size}")
# Out:
# List of cities: ['City 1' 'City 2' 'City 3' 'City 4' 'City 5']
# Number of cities: 5

# %% [markdown]
# ### Number of research centres/city

# %%
## Number of research centres/city
df_res_centre = df.groupby(["city"]).size()
df_res_centre
# Out:
# city
# City 1    11
# City 2     6
# City 3    14
# City 4    10
# City 5     9
# dtype: int64

# %%
plt.bar(number_of_cities,df_res_centre,
        edgecolor='k',
        color='dodgerblue')
plt.ylabel('Number of research centres')
plt.title('Number of research centres in each city')
plt.show()

# %% [markdown]
# ### Internal facilites histogram

# %%
plt.hist(df["internalFacilitiesCount"], 
         edgecolor="k",
         color='dodgerblue')
plt.xlabel("Internal Facilities Count")
plt.ylabel("Frequency")
plt.title("Distribution of Internal Facility Counts")
plt.show()

# %% [markdown]
# ### Number of facilities/research centre

# %%
## Number of facilities/research centre

plt.figure(figsize=(20, 6))
plt.bar(df["researchCenterName"], 
        df["internalFacilitiesCount"],
        edgecolor='k')
plt.xlabel("Research Centre Name")
plt.ylabel("Number of Facilities")
plt.title("Number of Facilities per Research Centre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Number of facilities/city

# %%
## Number of facilities/city
facilities_per_city = (df.groupby('city')['internalFacilitiesCount'].sum().reset_index())
facilities_per_city
# Out:
#      city  internalFacilitiesCount
# 0  City 1                       72
# 1  City 2                       32
# 2  City 3                       71
# 3  City 4                       54
# 4  City 5                       54

# %%
plt.bar(facilities_per_city['city'],
        facilities_per_city['internalFacilitiesCount'],
        edgecolor='k')
plt.xlabel('')
plt.ylabel('Number of Facilities')
plt.title('Number of Facilities by City')
plt.show()

# %% [markdown]
# ### Facility diversity/city

# %%
## Facility diversity/city
fac_diversity_per_city = (df.groupby('city')['facilityDiversity_10km'].sum().reset_index())
fac_diversity_per_city
# Out:
#      city  facilityDiversity_10km
# 0  City 1                7.121104
# 1  City 2                3.493221
# 2  City 3                7.025578
# 3  City 4                5.423671
# 4  City 5                5.378554

# %%
plt.bar(fac_diversity_per_city['city'],
        fac_diversity_per_city['facilityDiversity_10km'],
        edgecolor='k')
plt.xlabel('')
plt.ylabel('Facility Diversity')
plt.title('Facility Diversity by City')
plt.show()

# %% [markdown]
# ### Facility density/city

# %%
## Facility density/city
fac_density_per_city = (df.groupby('city')['facilityDensity_10km'].sum().reset_index())
fac_density_per_city
# Out:
#      city  facilityDensity_10km
# 0  City 1              4.101383
# 1  City 2              1.933100
# 2  City 3              4.206882
# 3  City 4              2.893410
# 4  City 5              2.923403

# %%
plt.bar(fac_density_per_city['city'],
        fac_density_per_city['facilityDensity_10km'],
        edgecolor='k')
plt.xlabel('')
plt.ylabel('Facility Density')
plt.title('Facility Density by City')
plt.show()

# %% [markdown]
# ### Number of hospitals per city

# %%
## Number of hospitals per city
hospitals_per_city = (df.groupby('city')['hospitals_10km'].sum().reset_index())
hospitals_per_city
# Out:
#      city  hospitals_10km
# 0  City 1              22
# 1  City 2              12
# 2  City 3              22
# 3  City 4              20
# 4  City 5              17

# %%
plt.bar(hospitals_per_city['city'],
        hospitals_per_city['hospitals_10km'],
        edgecolor='k')
plt.xlabel('')
plt.ylabel('Number of hospitals')
plt.title('Number of hospitals by City')
plt.show()

# %% [markdown]
# ### Number of pharmacies per city

# %%
## Number of pharmacies per city
pharmacies_per_city = (df.groupby('city')['pharmacies_10km'].sum().reset_index())
pharmacies_per_city
# Out:
#      city  pharmacies_10km
# 0  City 1               34
# 1  City 2               16
# 2  City 3               27
# 3  City 4               16
# 4  City 5               19

# %%
plt.bar(pharmacies_per_city['city'],
        pharmacies_per_city['pharmacies_10km'],
        edgecolor='k')
plt.xlabel('')
plt.ylabel('Number of pharmacies')
plt.title('Number of pharmacies by City')
plt.show()

# %% [markdown]
# ### Hospital access

# %%
sns.scatterplot(
    data=hospitals_per_city,
    x='city',
    y='hospitals_10km',
    size='hospitals_10km',
    sizes=(50,300),
    edgecolor='k')
plt.title('Number of Hospitals per City')
plt.legend(bbox_to_anchor=(1.05, 1), 
           loc=2)
plt.show()

# %% [markdown]
# ### Pharmacy access

# %%
sns.scatterplot(
    data=pharmacies_per_city,
    x='city',
    y='pharmacies_10km',
    size='pharmacies_10km',
    sizes=(50,300),
    edgecolor='k')
plt.title('Number of Pharmacies per City')
plt.legend(bbox_to_anchor=(1.05, 1), 
           loc=2)
plt.show()

# %% [markdown]
# ## Features Selection

# %% [markdown]
# ### Correlation between features

# %%
# Correlation between features
cols = [
    'internalFacilitiesCount',
    'hospitals_10km',
    'pharmacies_10km',
    'facilityDensity_10km',
    'facilityDiversity_10km']

correlation = df[cols].corr()
correlation
# Out:
#                          internalFacilitiesCount  hospitals_10km  \
# internalFacilitiesCount                 1.000000        0.878828
# hospitals_10km                          0.878828        1.000000
# pharmacies_10km                         0.889402        0.801383
# facilityDensity_10km                    0.900576        0.868519
# facilityDiversity_10km                  0.903568        0.852964
#
#                          pharmacies_10km  facilityDensity_10km  \
# internalFacilitiesCount         0.889402              0.900576
# hospitals_10km                  0.801383              0.868519
# pharmacies_10km                 1.000000              0.832407
# facilityDensity_10km            0.832407              1.000000
# facilityDiversity_10km          0.834209              0.868877
#
#                          facilityDiversity_10km
# internalFacilitiesCount                0.903568
# hospitals_10km                         0.852964
# pharmacies_10km                        0.834209
# facilityDensity_10km                   0.868877
# facilityDiversity_10km                 1.000000

# %%
sns.heatmap(
    correlation,
    annot=True,
    cmap='Blues')

plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# ### Discussion

# %% [markdown]
# **Question 1:"Why were these features selected?"**
#
# *The original dataset contained a combination of numeric and non-numeric data. By investigating the numeric data (since non-numeric data consisted essentially of ID information), it was clear that `longitude` and `latitude` would describe geographic location, but they  don't offer information regarding research centre quality, and thus were not considered in further analysis.*
#
# *For this reason, the selected features from the dataset were  `internalFacilitiesCount`,`hospitals_10km`,    `pharmacies_10km`,`facilityDiversity_10km`,`facilityDensity_10km`.*
#
# ---
# **Question 2: "Which features have the highest correlation with overall facility diversity or quality?"**
#
# *By performing the EDA and correlation analysis, the features that had the highest correlation with facility diversity were `internalFacilitiesCount (0.90)`,`facilityDensity_10km (0.87)`, and `hospitals_10km (0.85)`.*
#
# *This suggests that researcher centres with higher capacity are in areas with denser and more diverse infrastructure, combined with healthcare availability.*

# %% [markdown]
# ### Normalisation
# This ensures that variables that are on different scales are comparable.

# %%
from sklearn.preprocessing import StandardScaler

features = [
    'internalFacilitiesCount',
    'hospitals_10km',
    'pharmacies_10km',
    'facilityDiversity_10km',
    'facilityDensity_10km']

X = df[features]
X
# Out:
#     internalFacilitiesCount  hospitals_10km  pharmacies_10km  \
# 0                         3               1                0
# 1                         2               1                1
# 2                         3               0                1
# 3                        11               4                4
# 4                        10               4                5
# 5                         4               2                1
# 6                         1               0                1
# 7                         8               3                3
# 8                         2               0                0
# 9                         2               1                1
# 10                        3               0                0
# 11                       10               4                5
# 12                        8               4                3
# 13                        5               2                2
# 14                       10               3                5
# 15                        8               4                3
# 16                        3               1                0
# 17                        2               1                0
# 18                        5               1                2
# 19                        4               1                1
# 20                        2               1                1
# 21                        9               3                5
# 22                        2               1                1
# 23                       10               3                5
# 24                        5               2                1
# 25                        3               1                0
# 26                        4               2                3
# 27                       11               3                5
# 28                        9               3                4
# 29                        3               0                0
# 30                        5               2                1
# 31                        1               0                0
# 32                        4               1                2
# 33                        4               2                3
# 34                        5               1                1
# 35                       11               4                3
# 36                        4               1                3
# 37                        4               2                2
# 38                       10               3                4
# 39                        2               0                1
# 40                        8               4                3
# 41                        6               2                3
# 42                        6               1                3
# 43                        6               1                3
# 44                        7               2                2
# 45                       11               3                5
# 46                        9               3                4
# 47                        6               1                2
# 48                        9               4                4
# 49                        3               0                0
#
#     facilityDiversity_10km  facilityDensity_10km
# 0                 0.374488              0.177506
# 1                 0.391903              0.108965
# 2                 0.293552              0.076155
# 3                 0.884502              0.697016
# 4                 0.842611              0.568983
# 5                 0.458282              0.214188
# 6                 0.143468              0.123418
# 7                 0.992984              0.523311
# 8                 0.297995              0.172583
# 9                 0.287306              0.094345
# 10                0.312057              0.159351
# 11                0.814739              0.694969
# 12                0.705423              0.548168
# 13                0.570310              0.206263
# 14                0.741848              0.487643
# 15                0.769268              0.472308
# 16                0.330566              0.056541
# 17                0.354601              0.070493
# 18                0.643034              0.373414
# 19                0.691514              0.369783
# 20                0.279370              0.188281
# 21                0.856820              0.528262
# 22                0.175535              0.124587
# 23                0.956897              0.521352
# 24                0.602707              0.347043
# 25                0.279055              0.116875
# 26                0.450848              0.311360
# 27                0.810896              0.472648
# 28                0.969165              0.670125
# 29                0.119515              0.192333
# 30                0.657508              0.265192
# 31                0.340659              0.061183
# 32                0.448242              0.309747
# 33                0.406175              0.393982
# 34                0.468381              0.285422
# 35                0.885244              0.583496
# 36                0.694099              0.215069
# 37                0.600696              0.316137
# 38                0.765629              0.567431
# 39                0.293531              0.150339
# 40                0.816603              0.481405
# 41                0.525223              0.244422
# 42                0.626665              0.245760
# 43                0.512675              0.218796
# 44                0.664984              0.264869
# 45                0.972796              0.477634
# 46                0.811048              0.404637
# 47                0.497555              0.345921
# 48                0.860732              0.427087
# 49                0.192418              0.131381

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Visualising the scaled data as a dataframe
X_scaled = pd.DataFrame(X_scaled, columns=features)
X_scaled
# Out:
#     internalFacilitiesCount  hospitals_10km  pharmacies_10km  \
# 0                 -0.853881       -0.648176        -1.342883
# 1                 -1.174889       -0.648176        -0.743382
# 2                 -0.853881       -1.401868        -0.743382
# 3                  1.714182        1.612902         1.055123
# 4                  1.393174        1.612902         1.654624
# 5                 -0.532873        0.105517        -0.743382
# 6                 -1.495897       -1.401868        -0.743382
# 7                  0.751158        0.859210         0.455621
# 8                 -1.174889       -1.401868        -1.342883
# 9                 -1.174889       -0.648176        -0.743382
# 10                -0.853881       -1.401868        -1.342883
# 11                 1.393174        1.612902         1.654624
# 12                 0.751158        1.612902         0.455621
# 13                -0.211865        0.105517        -0.143880
# 14                 1.393174        0.859210         1.654624
# 15                 0.751158        1.612902         0.455621
# 16                -0.853881       -0.648176        -1.342883
# 17                -1.174889       -0.648176        -1.342883
# 18                -0.211865       -0.648176        -0.143880
# 19                -0.532873       -0.648176        -0.743382
# 20                -1.174889       -0.648176        -0.743382
# 21                 1.072166        0.859210         1.654624
# 22                -1.174889       -0.648176        -0.743382
# 23                 1.393174        0.859210         1.654624
# 24                -0.211865        0.105517        -0.743382
# 25                -0.853881       -0.648176        -1.342883
# 26                -0.532873        0.105517         0.455621
# 27                 1.714182        0.859210         1.654624
# 28                 1.072166        0.859210         1.055123
# 29                -0.853881       -1.401868        -1.342883
# 30                -0.211865        0.105517        -0.743382
# 31                -1.495897       -1.401868        -1.342883
# 32                -0.532873       -0.648176        -0.143880
# 33                -0.532873        0.105517         0.455621
# 34                -0.211865       -0.648176        -0.743382
# 35                 1.714182        1.612902         0.455621
# 36                -0.532873       -0.648176         0.455621
# 37                -0.532873        0.105517        -0.143880
# 38                 1.393174        0.859210         1.055123
# 39                -1.174889       -1.401868        -0.743382
# 40                 0.751158        1.612902         0.455621
# 41                 0.109143        0.105517         0.455621
# 42                 0.109143       -0.648176         0.455621
# 43                 0.109143       -0.648176         0.455621
# 44                 0.430151        0.105517        -0.143880
# 45                 1.714182        0.859210         1.654624
# 46                 1.072166        0.859210         1.055123
# 47                 0.109143       -0.648176        -0.143880
# 48                 1.072166        1.612902         1.055123
# 49                -0.853881       -1.401868        -1.342883
#
#     facilityDiversity_10km  facilityDensity_10km
# 0                -0.786850             -0.794887
# 1                -0.716344             -1.174139
# 2                -1.114522             -1.355681
# 3                 1.277957              2.079667
# 4                 1.108360              1.371232
# 5                -0.447607             -0.591916
# 6                -1.722139             -1.094166
# 7                 1.717151              1.118522
# 8                -1.096533             -0.822124
# 9                -1.139808             -1.255032
# 10               -1.039603             -0.895341
# 11                0.995517              2.068341
# 12                0.552948              1.256061
# 13                0.005941             -0.635770
# 14                0.700418              0.921166
# 15                0.811429              0.836310
# 16               -0.964669             -1.464212
# 17               -0.867363             -1.387009
# 18                0.300366              0.289115
# 19                0.496637              0.269020
# 20               -1.171938             -0.735265
# 21                1.165884              1.145918
# 22               -1.592318             -1.087696
# 23                1.571051              1.107685
# 24                0.137101              0.143197
# 25               -1.173213             -1.130370
# 26               -0.477705             -0.054244
# 27                0.979962              0.838193
# 28                1.620716              1.930875
# 29               -1.819113             -0.712846
# 30                0.358963             -0.309703
# 31               -0.923807             -1.438526
# 32               -0.488253             -0.063172
# 33               -0.658563              0.402919
# 34               -0.406723             -0.197768
# 35                1.280962              1.451537
# 36                0.507106             -0.587041
# 37                0.128962             -0.027811
# 38                0.796697              1.362644
# 39               -1.114607             -0.945208
# 40                1.003066              0.886646
# 41               -0.176594             -0.424629
# 42                0.234097             -0.417225
# 43               -0.227396             -0.566418
# 44                0.389232             -0.311489
# 45                1.635418              0.865782
# 46                0.980574              0.461875
# 47               -0.288610              0.136989
# 48                1.181725              0.586095
# 49               -1.523965             -1.050105

# %% [markdown]
# ## Clustering model

# %%
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score
import joblib

# %% [markdown]
# ### K-Means

# %% [markdown]
# #### Calculating the K-Means

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)

# %%
kmeans
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
labels
# Out:
# array([2, 2, 2, 1, 1, 0, 2, 1, 2, 2, 2, 1, 1, 0, 1, 1, 2, 2, 0, 0, 2, 1,
#        2, 1, 0, 2, 0, 1, 1, 2, 0, 2, 0, 0, 0, 1, 0, 0, 1, 2, 1, 0, 0, 0,
#        0, 1, 1, 0, 1, 2], dtype=int32)

# %% [markdown]
# #### Visualising clusters as a dataframe

# %%
# Visualising clusters as a dataframe
df["cluster"] = labels

summary = df.groupby("cluster")[features].mean()
summary
# Out:
#          internalFacilitiesCount  hospitals_10km  pharmacies_10km  \
# cluster
# 0                       4.941176        1.529412         2.058824
# 1                       9.529412        3.470588         4.117647
# 2                       2.312500        0.500000         0.437500
#
#          facilityDiversity_10km  facilityDensity_10km
# cluster
# 0                      0.559935              0.289845
# 1                      0.850424              0.536852
# 2                      0.279126              0.125271

# %%
df.head()
# Out:
#   researchCenterId  researchCenterName    city  latitude  longitude  \
# 0           RC-014  Research Center 14  City 4   50.7713    -1.9260
# 1           RC-040  Research Center 40  City 2   50.5088    -1.3637
# 2           RC-031  Research Center 31  City 4   50.2202    -1.2889
# 3           RC-046  Research Center 46  City 5   50.9362    -1.3040
# 4           RC-018  Research Center 18  City 2   50.0254    -1.8921
#
#    internalFacilitiesCount  hospitals_10km  pharmacies_10km  \
# 0                        3               1                0
# 1                        2               1                1
# 2                        3               0                1
# 3                       11               4                4
# 4                       10               4                5
#
#    facilityDiversity_10km  facilityDensity_10km  cluster
# 0                0.374488              0.177506        2
# 1                0.391903              0.108965        2
# 2                0.293552              0.076155        2
# 3                0.884502              0.697016        1
# 4                0.842611              0.568983        1

# %% [markdown]
# #### Assigning a tier to each cluster

# %%
# Assigning a tier to each cluster
cluster_to_tier = {
    1: "Premium",
    0: "Standard",
    2: "Basic"}

# %% [markdown]
# #### Adding clustering info to the dataframe

# %%
# Adding clustering info to the dataframe
df["qualityTier"] = df["cluster"].map(cluster_to_tier)
df.head()
# Out:
#   researchCenterId  researchCenterName    city  latitude  longitude  \
# 0           RC-014  Research Center 14  City 4   50.7713    -1.9260
# 1           RC-040  Research Center 40  City 2   50.5088    -1.3637
# 2           RC-031  Research Center 31  City 4   50.2202    -1.2889
# 3           RC-046  Research Center 46  City 5   50.9362    -1.3040
# 4           RC-018  Research Center 18  City 2   50.0254    -1.8921
#
#    internalFacilitiesCount  hospitals_10km  pharmacies_10km  \
# 0                        3               1                0
# 1                        2               1                1
# 2                        3               0                1
# 3                       11               4                4
# 4                       10               4                5
#
#    facilityDiversity_10km  facilityDensity_10km  cluster qualityTier
# 0                0.374488              0.177506        2       Basic
# 1                0.391903              0.108965        2       Basic
# 2                0.293552              0.076155        2       Basic
# 3                0.884502              0.697016        1     Premium
# 4                0.842611              0.568983        1     Premium

# %% [markdown]
# #### Saving the model

# %%
# Create a pipeline to save the model
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("kmeans", KMeans(n_clusters=3, random_state=42, n_init=10))])

pipeline.fit(X)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('kmeans', KMeans(n_clusters=3, n_init=10, random_state=42))])

# %%
# Saving the file using joblib
joblib.dump(pipeline, "clustering_pipeline.joblib")
# Out:
# ['clustering_pipeline.joblib']

# %% [markdown]
# ### Silhouette Score

# %%
score = silhouette_score(X_scaled, labels)
print(score)
# Out:
# 0.5519201011808984

# %% [markdown]
# ## Model interpretation

# %% [markdown]
# ### Which cluster has the highest internal facility counts and external healthcare access?

# %% [markdown]
# *From `# Visualising clusters as a dataframe`, we have features' averages:*
#
# | cluster | internalFacilitiesCount | hospitals_10km | pharmacies_10km | facilityDiversity_10km | facilityDensity_10km |
# |---------|------------------------|----------------|-----------------|------------------------|----------------------|
# | 0 | 4.941176 | 1.529412 | 2.058824 | 0.559935 | 0.289845 |
# | 1 | 9.529412 | 3.470588 | 4.117647 | 0.850424 | 0.536852 |
# | 2 | 2.312500 | 0.500000 | 0.437500 | 0.279126 | 0.125271 |
#
# *`Cluster 1` has the **highest averages** for all features, while `Cluster 2` has the **lowest**. `Cluster 0` is **intermediary**.*
#
# ---

# %% [markdown]
# ### Are high-quality centers concentrated in specific cities?

# %% [markdown]
# *Now, if we investigate if there is a concentration of high-quality centres in specific cities, we can verify the following:*

# %%
city_tier_counts = df.groupby(["city", "qualityTier"]).size().unstack(fill_value=0)
city_tier_counts
# Out:
# qualityTier  Basic  Premium  Standard
# city
# City 1           1        4         6
# City 2           2        2         2
# City 3           5        4         5
# City 4           5        4         1
# City 5           3        3         3

# %% [markdown]
# *Observing the table above, we can see that all cities have similar numbers of Premium centres. Some cities have more research centres than others (City 1 has only 1 Basic centre, compared to City 3 and City 4, that have 5). But focusing solely in the Premium centres, the number is very similar in all cities.*
#
# *In terms of density, we can observe:*

# %%
city_tier_counts = city_tier_counts[["Basic", "Standard", "Premium"]]
city_tier_counts.plot(kind="bar", 
                      stacked=True,
                      cmap='tab20c_r',
                      edgecolor='k')

plt.title("Distribution of Research Centre Quality Tiers by City")
plt.xlabel("")
plt.ylabel("Number of Research Centres")
plt.legend(title="Quality Tier")


plt.show()

# %% [markdown]
# *This shows that **Premium centres appear in similar number in all cities**, but **City 3 has the largest number** of centres, while **City 2 has the lowest**.*

# %% [markdown]
# ### Does diversity or density play a stronger role?

# %% [markdown]
# *If we revisit `# Visualising clusters as a dataframe` averages, we see:*
#
# | cluster | internalFacilitiesCount | hospitals_10km | pharmacies_10km | facilityDiversity_10km | facilityDensity_10km |
# |---------|------------------------|----------------|-----------------|------------------------|----------------------|
# | 0 | 4.941176 | 1.529412 | 2.058824 | 0.559935 | 0.289845 |
# | 1 | 9.529412 | 3.470588 | 4.117647 | 0.850424 | 0.536852 |
# | 2 | 2.312500 | 0.500000 | 0.437500 | 0.279126 | 0.125271 |
#
# *And if we visualise it in a line plot:*

# %%
x = [0, 1, 2]
clusters = [2, 0, 1]

plt.plot(x,
         summary.loc[clusters, 'facilityDiversity_10km'],
         marker='o',
         label='Diversity')

plt.plot(x,
         summary.loc[clusters, 'facilityDensity_10km'],
         marker='o',
         label='Density')

plt.legend()
plt.xticks(x, ['Basic', 'Standard', 'Premium'])
plt.ylabel("Value")
plt.tight_layout()
plt.title("Facility Diversity and Density Trend")
plt.show()

# %% [markdown]
# *We can observe that `facilityDiversity_10km` shows a larger separation between the clusters, with increasing values as we move from **Basic** $\rightarrow$ **Standard** $\rightarrow$ **Premium**, although `facilityDensity_10km` also displays a similar trend, indicating it also contributes to the clustering.*

# %% [markdown]
# ## API Deployment (FastAPI)

# %%
from fastapi import FastAPI
import pandas as pd
import joblib

app = FastAPI()

model = joblib.load("clustering_pipeline.joblib")

cluster_to_category = {
    1: "Premium",
    0: "Standard",
    2: "Basic"}

@app.post("/predict")
def predict(data: dict):
    X_new = pd.DataFrame([data])
    cluster = int(model.predict(X_new)[0])
    category = cluster_to_category[cluster]
    return {"predictedCategory": category}
